# %% [markdown]
# # Pytorch Workflow
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# What_we_are_Learning
#
#     1: "data (prepare and load)",
#     2: "build model",
#     3: "fitting the model to data (training)",
#     4: "making predictions and evaluating a model(inference)",
#     5: "saving and loading model",
#     6: "putting it all together"

# %%
import torch
from torch import nn  # nn contains all of Pytorch's building blocks
import matplotlib.pyplot as plt

# Check PyTorch version
torch.__version__
# Out:
# '2.6.0+cu124'

# %% [markdown]
# # Data (preparing and loading)
#
# * Excel spreedsheet
# * Image of any kind
# * Videos
# * Audio like songs or podcasts
# * DNA
# * Text
#
# # Machine Learning : a game of two parts
#
# * Data into numbers
# * Build the model to learn patterns

# %%
# Create known parameters
weight = 0.7
bias = 0.3

# Create
start = 0
end = 1
step = 0.02
X = torch.arange(start, end, step).unsqueeze(dim=1)
y = X * weight + bias

X[:10], y[:10]
# Out:
# (tensor([[0.0000],
#          [0.0200],
#          [0.0400],
#          [0.0600],
#          [0.0800],
#          [0.1000],
#          [0.1200],
#          [0.1400],
#          [0.1600],
#          [0.1800]]),
#  tensor([[0.3000],
#          [0.3140],
#          [0.3280],
#          [0.3420],
#          [0.3560],
#          [0.3700],
#          [0.3840],
#          [0.3980],
#          [0.4120],
#          [0.4260]]))

# %% [markdown]
# ## Spliting data into traing and testing sets
#
# * `Trainin set` : 60-80%
# * `Validation set` : 10-20%
# * `Testing set` : 10-20%

# %%
train_split = int(0.8 * len(X))
X_train, y_train = X[:train_split], y[:train_split]
X_test, y_test = X[train_split:], y[train_split:]

len(X_train), len(y_train), len(X_test), len(y_test)
# Out:
# (40, 40, 10, 10)

# %% [markdown]
# # Data Visualization to understand the data

# %%
plt.plot(X_train, y_train, label="Training Data")
plt.plot(X_test, y_test, label="Testing Data")
plt.legend()

# %%
def plot_predictions(train_data=X_train,
                     train_labels=y_train,
                     test_data=X_test,
                     test_labels=y_test,
                     predictions=None):

  plt.figure(figsize=(10, 7))

  # Plot training data in blue
  plt.scatter(train_data, train_labels, c="b", s=4,label="Training Data")

  # Plot test data in green
  plt.scatter(test_data, test_labels, c="g", s=4, label="Testing Data")

  # Are there predictions?
  if predictions is not None:
    # Plot predictions in red (predictions in test data)
    plt.scatter(test_data, predictions, c="r", s=4, label="Predictions")

  # Show the legend
  plt.legend(prop={"size": 14})

# %%
plot_predictions()

# %% [markdown]
# ## Building model

# %%
# Create linear regression model class
class LinearRegressionModel(nn.Module): # Module -> base class for neural network
  def __init__(self):
    super().__init__()
    self.weights = nn.Parameter(torch.randn(1,
                                            requires_grad=True,
                                            dtype=torch.float))
    self.bias = nn.Parameter(torch.randn(1,
                                         requires_grad=True,
                                         dtype=torch.float))

  # Forward defines the computation in the model
  def forward(self, x: torch.Tensor) -> torch.Tensor: # 'x' is input data
    return self.weights * x + self.bias # this is linear regression

# %% [markdown]
# ### PyTorch Building essentials
#
# * torch.nn
# * torch.nn.Parameter
# * torch.nn.Module
# * torch.optim
# * def forward()

# %%
torch.manual_seed(42)

model_0 = LinearRegressionModel()

list(model_0.parameters())
# Out:
# [Parameter containing:
#  tensor([0.3367], requires_grad=True),
#  Parameter containing:
#  tensor([0.1288], requires_grad=True)]

# %%
model_0.state_dict()
# Out:
# OrderedDict([('weights', tensor([0.3367])), ('bias', tensor([0.1288]))])

# %%
weight, bias
# Out:
# (0.7, 0.3)

# %% [markdown]
# ### Making prediction using `torch.inference_mode`

# %%
X_test
# Out:
# tensor([[0.8000],
#         [0.8200],
#         [0.8400],
#         [0.8600],
#         [0.8800],
#         [0.9000],
#         [0.9200],
#         [0.9400],
#         [0.9600],
#         [0.9800]])

# %%
with torch.inference_mode():
  y_preds = model_0(X_test)

y_preds
# Out:
# tensor([[0.3982],
#         [0.4049],
#         [0.4116],
#         [0.4184],
#         [0.4251],
#         [0.4318],
#         [0.4386],
#         [0.4453],
#         [0.4520],
#         [0.4588]])

# %%
y_test
# Out:
# tensor([[0.8600],
#         [0.8740],
#         [0.8880],
#         [0.9020],
#         [0.9160],
#         [0.9300],
#         [0.9440],
#         [0.9580],
#         [0.9720],
#         [0.9860]])

# %%
plot_predictions(predictions=y_preds)

# %% [markdown]
# # Train Model
# from poor representation to good representation
#
# * Note : use loss/cost function - to get to know how poor its predicting
#
# Things to train:
# * **Loss function**
# * **Optimizers**
#
# In PyTorch we need:
# * training loop
# * testing loop

# %%
loss_fn = nn.L1Loss()

optimizer = torch.optim.SGD(model_0.parameters(),
                            lr=0.01)

# %% [markdown]
# ### Building training loop ( and a testing loop) in  PyTorch
# 0. loop through the data
# 1. forward pass / **forward propogation**
# 2. calculate the loss
# 3. Optimizer zero grad
# 4. Loss Backward / **Back Propogation**
# 5. Optimizer step / **Gradient descent**

# %%
epochs = 200 # loop

train_losses = []
test_losses = []
epoch_count = []

# training
# 0.loop through the data
for epoch in range(epochs):
  # Set to training mode
  model_0.train()

  #1. Forward pass
  y_pred = model_0(X_train)

  # 2. Calculate loss
  loss = loss_fn(y_pred, y_train)

  #3. Optimizer zero grad
  optimizer.zero_grad()

  # 4. Back Propogation
  loss.backward()

  # 5. optimizer
  optimizer.step()

  # testing
  model_0.eval() # turns of gradient

  with torch.inference_mode():  # turns off gradient tracking

    # 1. forward pass
    test_pred = model_0(X_test)

    # 2. Calculate the loss
    test_loss = loss_fn(test_pred, y_test)

    train_losses.append(loss.detach().numpy())
    test_losses.append(test_loss.detach().numpy())
    epoch_count.append(epoch)
  if epoch % 10 == 0:
    print(f"Epoch: {epoch} | Loss: {loss} | Test Loss: {test_loss}")

    print(model_0.state_dict())
# Out:
# Epoch: 0 | Loss: 0.31288138031959534 | Test Loss: 0.48106518387794495
# OrderedDict([('weights', tensor([0.3406])), ('bias', tensor([0.1388]))])
# Epoch: 10 | Loss: 0.1976713240146637 | Test Loss: 0.3463551998138428
# OrderedDict([('weights', tensor([0.3796])), ('bias', tensor([0.2388]))])
# Epoch: 20 | Loss: 0.08908725529909134 | Test Loss: 0.21729660034179688
# OrderedDict([('weights', tensor([0.4184])), ('bias', tensor([0.3333]))])
# Epoch: 30 | Loss: 0.053148526698350906 | Test Loss: 0.14464017748832703
# OrderedDict([('weights', tensor([0.4512])), ('bias', tensor([0.3768]))])
# Epoch: 40 | Loss: 0.04543796554207802 | Test Loss: 0.11360953003168106
# OrderedDict([('weights', tensor([0.4748])), ('bias', tensor([0.3868]))])
# Epoch: 50 | Loss: 0.04167863354086876 | Test Loss: 0.09919948130846024
# OrderedDict([('weights', tensor([0.4938])), ('bias', tensor([0.3843]))])
# Epoch: 60 | Loss: 0.03818932920694351 | Test Loss: 0.08886633068323135
# ...

# %%
# plot losses
plt.plot(epoch_count, train_losses, label="Tarining losses")
plt.plot(epoch_count, test_losses, label="Test losses")
plt.title("Training and test loss curves")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.legend();

# %%
with torch.inference_mode():
  y_preds_new = model_0(X_test)

# %%
plot_predictions(predictions=y_preds)

# %%
plot_predictions(predictions=y_preds_new)

# %%
# accuracy
from sklearn.metrics import r2_score

r2_score(y_test, y_preds_new.detach().numpy())
# Out:
# 0.9558627009391785

# %% [markdown]
# # Saving Model in PyTorch
#
# 3 main methods:
#
# 1. `torch.save()` - allows you to save a PyTorch object in Python's pickel formate
# 2. `torch.load()` - allow to load the saved PyTorch object
# 3. `torch.nn.Module.load_sate_dict()` - this allows to load a model's saved state dictionary

# %%
model_0.state_dict()
# Out:
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])

# %%
# Saving our PyTorch model
from pathlib import Path

# 1. Create models directory
MODEL_PATH = Path("models")
MODEL_PATH.mkdir(parents=True, exist_ok=True)

# 2. Create model save path
MODEL_NAME = "01_pytorch_workflow_model.pth"
MODEL_SAVE_PATH = MODEL_PATH / MODEL_NAME

# 3. Save the model state dict
print(f"Saving model to: {MODEL_SAVE_PATH}")
torch.save(obj=model_0.state_dict(),
           f=MODEL_SAVE_PATH)
# Out:
# Saving model to: models/01_pytorch_workflow_model.pth

# %%
# !ls -l models
# Out:
# total 4
# -rw-r--r-- 1 root root 1668 Apr 17 13:04 01_pytorch_workflow_model.pth

# %% [markdown]
# # Loading
# `torch.load()`

# %%
# to load in a saved state_dict we have to instantiate a new instance of our model class
loaded_model_0 = LinearRegressionModel()

# Load the saved state of model_0
loaded_model_0.load_state_dict(torch.load(f=MODEL_SAVE_PATH))
# Out:
# <All keys matched successfully>

# %%
loaded_model_0.state_dict()
# Out:
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])

# %%
# Make some prediction
loaded_model_0.eval()
with torch.inference_mode():
  loaded_model_preds = loaded_model_0(X_test)

loaded_model_preds
# Out:
# tensor([[0.8685],
#         [0.8825],
#         [0.8965],
#         [0.9105],
#         [0.9245],
#         [0.9384],
#         [0.9524],
#         [0.9664],
#         [0.9804],
#         [0.9944]])

# %%
model_0.eval()
with torch.inference_mode():
  y_preds = model_0(X_test)

y_preds
# Out:
# tensor([[0.8685],
#         [0.8825],
#         [0.8965],
#         [0.9105],
#         [0.9245],
#         [0.9384],
#         [0.9524],
#         [0.9664],
#         [0.9804],
#         [0.9944]])

# %%
# Compare loaded model pred with original model preds
y_preds_new == loaded_model_preds
# Out:
# tensor([[True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True]])

# %% [markdown]
# ## Putting it all together

# %%
import torch
from torch import nn
import matplotlib.pyplot as plt

torch.__version__
# Out:
# '2.6.0+cu124'

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
weight = 0.6
bias = 0.2
start = 0
end = 1
step = 0.02
X = torch.arange(start, end, step).unsqueeze(dim=1)
y = X * weight + bias

train_split = int(0.8 * len(X))
X_train, y_train = X[:train_split], y[:train_split]
X_test, y_test = X[train_split:], y[train_split:]

len(X_train), len(y_train), len(X_test), len(y_test)
# Out:
# (40, 40, 10, 10)

# %%
def plot_predictions(train_data=X_train,
                     train_labels=y_train,
                     test_data=X_test,
                     test_labels=y_test,
                     predictions=None):

  plt.figure(figsize=(10, 7))

  # Plot training data in blue
  plt.scatter(train_data, train_labels, c="b", s=4,label="Training Data")

  # Plot test data in green
  plt.scatter(test_data, test_labels, c="g", s=4, label="Testing Data")

  # Are there predictions?
  if predictions is not None:
    # Plot predictions in red (predictions in test data)
    plt.scatter(test_data, predictions, c="r", s=4, label="Predictions")

  # Show the legend
  plt.legend(prop={"size": 14})

# %%
plot_predictions(X_train, y_train, X_test, y_test)

# %%
class LinearRegressionModelV2(nn.Module):
  def __init__(self, ):
    super().__init__()

    # Use nn.Linear()
    self.linear_layer = nn.Linear(in_features=1,
                                  out_features=1)

  def forward(self, x):
    return self.linear_layer(x)

# %%
torch.manual_seed(42)
model_1 = LinearRegressionModelV2()
model_1, model_1.state_dict()
# Out:
# (LinearRegressionModelV2(
#    (linear_layer): Linear(in_features=1, out_features=1, bias=True)
#  ),
#  OrderedDict([('linear_layer.weight', tensor([[0.7645]])),
#               ('linear_layer.bias', tensor([0.8300]))]))

# %%
loss_fn = nn.L1Loss()

optimizer = torch.optim.SGD(model_1.parameters(),
                            lr=0.01)

# %%
epochs = 200

epoch_count = []
train_losses = []
test_losses = []

for epoch in range(epochs):
  model_1.train()
  y_pred = model_1(X_train)
  loss = loss_fn(y_pred, y_train)
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()

  model_1.eval()
  with torch.inference_mode():
    test_pred = model_1(X_test)
    test_loss = loss_fn(test_pred, y_test)

    train_losses.append(loss.detach().numpy())
    test_losses.append(test_loss.detach().numpy())
    epoch_count.append(epoch)

  if epoch % 20 == 0:
    print(f"Epoch: {epoch} | Loss: {loss} | Test Loss: {test_loss}")
    print(model_1.state_dict())
# Out:
# Epoch: 0 | Loss: 0.6941779851913452 | Test Loss: 0.7629762291908264
# OrderedDict([('linear_layer.weight', tensor([[0.7606]])), ('linear_layer.bias', tensor([0.8200]))])
# Epoch: 20 | Loss: 0.4637581706047058 | Test Loss: 0.49355649948120117
# OrderedDict([('linear_layer.weight', tensor([[0.6826]])), ('linear_layer.bias', tensor([0.6200]))])
# Epoch: 40 | Loss: 0.23333843052387238 | Test Loss: 0.22413687407970428
# OrderedDict([('linear_layer.weight', tensor([[0.6046]])), ('linear_layer.bias', tensor([0.4200]))])
# Epoch: 60 | Loss: 0.01466408371925354 | Test Loss: 0.027661234140396118
# OrderedDict([('linear_layer.weight', tensor([[0.5341]])), ('linear_layer.bias', tensor([0.2310]))])
# Epoch: 80 | Loss: 0.006971584167331457 | Test Loss: 0.01527326088398695
# OrderedDict([('linear_layer.weight', tensor([[0.5671]])), ('linear_layer.bias', tensor([0.2140]))])
# Epoch: 100 | Loss: 0.0036876772064715624 | Test Loss: 0.012758761644363403
# ...

# %%
# Plot the losses
plt.plot(epoch_count, train_losses, label="Training loss")
plt.plot(epoch_count, test_losses, label="Test loss")
plt.title("Training and test loss curves")
plt.ylabel("Loss")
plt.xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')

# %%
with torch.inference_mode():
  y_preds = model_1(X_test)

# %%
plot_predictions(predictions=y_preds)

# %%
from pathlib import Path

# 1. Create models directory
MODEL_PATH = Path("models")
MODEL_PATH.mkdir(parents=True, exist_ok=True)

MODEL_NAME = "01V_pytorch_workflow_model.pth"
MODEL_SAVE_PATH = MODEL_PATH / MODEL_NAME
print(f"Saving model to: {MODEL_SAVE_PATH}")
torch.save(obj=model_1.state_dict(),
           f=MODEL_SAVE_PATH)
# Out:
# Saving model to: models/01V_pytorch_workflow_model.pth

# %%
loaded_model_1 = LinearRegressionModelV2()
loaded_model_1.load_state_dict(torch.load(f=MODEL_SAVE_PATH))
# Out:
# <All keys matched successfully>

# %%
with torch.inference_mode():
  loaded_model_1_preds = loaded_model_1(X_test)

# %%
loaded_model_1_preds == y_preds
# Out:
# tensor([[True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True]])
